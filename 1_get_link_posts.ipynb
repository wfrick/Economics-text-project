# %% [markdown]
# # Get link roundups
#
# This notebook uses the Bing web search API to get the link roundup posts from Economist's View, an economics blog that regularly published links to economics writing from 2008 to 2019. The result is a csv with urls to these link-roundup posts: EV_links.csv

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64, json
from urllib.parse import urlparse
from keys import bing as key
import pandas as pd

# %%
def multiple_searches(value,site_list,max_results):
    #Takes a search term, site list, max results
    #Uses offset in Bing to do multiple searches, 50 results at a time
    count = 0
    all_links = []
    while count < max_results:
        results = bing(value,site_list,key,offset=count)
        for a in results:
            all_links.append(a)
        count += 50
        
    return all_links

def bing(value,site_list, key, offset):
    #Takes a search term (value), list of sites to search against, and bing api key
    #Returns list of urls
    #Documentation https://dev.cognitive.microsoft.com/docs/services/f40197291cd14401b93a478716e818bf/operations/56b4447dcf5ff8098cef380d
    
    if value != None:
        term = str(value)
        term = limit_search(term,site_list)
    
        number_of_results = 50
        #offset=0
        news=False
        #News = True means a Bing news search, else web search
    
        headers = {
            # Request headers
            'Ocp-Apim-Subscription-Key': key,
        }
    
        params = urllib.parse.urlencode({
            # Request parameters
            'q': term,
            'count': number_of_results,
            'offset': offset,
            'mkt': 'en-us',
            'safeSearch': 'Moderate'
        })
        
        try:
            conn = http.client.HTTPSConnection('api.cognitive.microsoft.com')
            conn.request("GET", "/bing/v7.0/search?%s" % params, "{body}", headers)
            response = conn.getresponse()
            data = response.read()
            conn.close()
            
            results = json.loads(data)
            #Return articles
            articles = []
            count = 0
    
            while count < number_of_results:
                if news == True:
                    url = results['value'][count]['url']
                else:
                    try:
                        url = results['webPages']['value'][count]['url']
                        articles.append(url)

                    except:
                        print("Error with Bing result")
                    
                count +=1
                
            print("One search done")
                        
            #return "Links! {}".format(str(articles))
            return articles
        
        except Exception as e:
            print("[Errno {0}] {1}".format(e.errno, e.strerror))
            print(e)
            
            
def limit_search(term,sites):
    #Concatenates site list to suit Bing API
    count = 0
    sites_string = ' ('
    if len(sites) > 0:
        while count < len(sites):
            if count == len(sites) - 1:
                site = 'site:'+str(sites[count])
                sites_string = sites_string + site
            else:
                site = 'site:'+str(sites[count])+' OR '
                sites_string = sites_string + site
            count +=1
        term = term + sites_string 
    return term

# %%
#Get link recommendations from Economist's View
sites = ['http://economistsview.typepad.com/']
year = 2008
all_links = []
while year < 2020:
    term = "Links for " + str(year)
    urls = multiple_searches(term,sites,365)
    year += 1
    all_links = all_links + urls
    
print(len(all_links))
# Out:
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# One search done
# One search done
# One search done
# One search done
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# Error with Bing result
# One search done
# 4416
# ['https://economistsview.typepad.com/economistsview/2008/06/links-for-2008.html', 'https://economistsview.typepad.com/economistsview/2008/08/links-for-2008.html', 'https://economistsview.typepad.com/economistsview/2008/07/links-for-200-7.html', 'https://economistsview.typepad.com/economistsview/2008/10/links-for-20-19.html', 'https://economistsview.typepad.com/economistsview/2008/12/links-for-20-24.html', 'https://economistsview.typepad.com/economistsview/2008/12/links-for-20-14.html', 'https://economistsview.typepad.com/economistsview/2008/08/links-for-20-18.html', 'https://economistsview.typepad.com/economistsview/2008/11/links-for-20-24.html', 'https://economistsview.typepad.com/economistsview/2008/11/links-for-20-15.html', 'https://economistsview.typepad.com/economistsview/2008/06/links-for-20-15.html', 'https://economistsview.typepad.com/economistsview/2008/02/links-for-20-22.html', 'https://economistsview.typepad.com/economistsview/2008/09/links-for-20-16.html', 'https://economistsview.typepad.com/economistsview/2008/10/links-for-20-29.html', 'https://economistsview.typepad.com/economistsview/2008/12/links-for-200-2.html', 'https://economistsview.typepad.com/economistsview/2008/10/links-for-20-12.html', 'https://economistsview.typepad.com/economistsview/2008/11/links-for-20-29.html', 'https://economistsview.typepad.com/economistsview/2008/12/links-for-200-9.html', 'https://economistsview.typepad.com/economistsview/2008/05/links-for-20-29.html', 'https://economistsview.typepad.com/economistsview/2008/02/links-for-200-9.html', 'https://economistsview.typepad.com/economistsview/2008/06/links-for-20-13.html', 'https://economistsview.typepad.com/economistsview/2008/11/links-for-20-17.html', 'https://economistsview.typepad.com/economistsview/2008/01/bloggers-block.html', 'https://economistsview.typepad.com/economistsview/2008/07/making-fannie-a.html', 'https://economistsview.typepad.com/economistsview/2008/12/when-handed-a-l.html', 'https://economistsview.typepad.com/economistsview/2008/07/wanted-a-new-co.html', 'https://economistsview.typepad.com/economistsview/2008/12/paul-krugman-fi.html', 'https://economistsview.typepad.com/economistsview/2008/06/paul-krugman-a.html', 'https://economistsview.typepad.com/economics421/2008/03/video-lecture-f.html', 'https://economistsview.typepad.com/economics421/winter_2008/', 'https://economistsview.typepad.com/economics421/2008/03/', 'https://economistsview.typepad.com/economistsview/2008/11/recession-why-w.html', 'https://economistsview.typepad.com/economistsview/2008/02/paul-krugman-th.html', 'https://economistsview.typepad.com/economistsview/2008/03/war-costs-and-c.html', 'https://economistsview.typepad.com/economistsview/2008/09/anti-intellectu.html', 'https://economistsview.typepad.com/economistsview/2008/04/obamas-touch-of.html', 'https://economistsview.typepad.com/economics493/2008/09/course-material.html', 'https://economistsview.typepad.com/economistsview/2008/10/free-trade-with.html', 'https://economistsview.typepad.com/economistsview/2008/05/who-gentrifies.html', 'https://economistsview.typepad.com/economistsview/2008/10/letting-lehman.html', 'https://economistsview.typepad.com/economistsview/2008/05/the-church-vers.html', 'https://economistsview.typepad.com/economics470/2010/10/class-materials-for-lecture-4.html', 'https://economistsview.typepad.com/economics421/winter_2009/', 'https://economistsview.typepad.com/economics421/syllabus/', 'https://economistsview.typepad.com/economics493/2010/01/class-materials-for-lecture-5.html', 'https://economistsview.typepad.com/economistsview/2008/10/links-for-200-5.html?p=1', 'https://economistsview.typepad.com/economistsview/2008/03/links-for-20-14.html', 'https://economistsview.typepad.com/economistsview/2008/05/links-for-20-29.html', 'https://economistsview.typepad.com/economistsview/2008/04/links-for-20-12.html', 'https://economistsview.typepad.com/economistsview/2008/02/links-for-200-3.html', 'https://economistsview.typepad.com/econom ...

# %%
#Create a dataframe
df = pd.DataFrame(columns = ["URL"])
#For all EV links, if 'links' in the url add to dataframe
for b in all_links:
    if 'links' in b:
        df.loc[len(df)] = b

#Print dataframe shape, save to CSV
print(df.shape)
df.to_csv("EV_links.csv")
# Out:
# (1092, 1)
