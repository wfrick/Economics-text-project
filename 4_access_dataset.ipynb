# %%
import pandas as pd

# %%
df = pd.read_csv("data.zip")
print(df.shape)
df.head()
# Out:
# (14175, 11)
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                  URL  \
# 0  https://www.nytimes.com/2008/06/01/weekinrevie...
# 1  https://www.nytimes.com/2008/06/01/opinion/01g...
# 2  https://www.washingtonpost.com/wp-dyn/content/...
# 3  http://www.guardian.co.uk/commentisfree/2008/j...
# 4  http://www.sciam.com/article.cfm?id=matter-ant...
#
#                                                Title                  Source  \
# 0  Think the Economy Is Bad? Wait Till the States...         www.nytimes.com
# 1  Put a Little Science in Your Life - The New Yo...         www.nytimes.com
# 2  Villains in the Mortgage Mess? Start at Wall S...  www.washingtonpost.com
# 3  What I told the Pope about how to shape the ne...      www.guardian.co.uk
# ...

# %%
#Save as a csv (~140mb)
df.to_csv("economics_text.csv")
